# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("data.csv")
df
# Out:
#     Hours_Studied  Marks_received
# 0             1.5              38
# 1             2.0              45
# 2             2.5              50
# 3             3.0              55
# 4             3.5              60
# 5             4.0              64
# 6             4.5              68
# 7             5.0              72
# 8             5.5              75
# 9             6.0              78
# 10            6.5              82
# 11            7.0              85
# 12            7.5              88
# 13            8.0              92
# 14            8.5              95
# 15            9.0              96

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(df.Hours_Studied, df.Marks_received,color='purple',marker='+')
plt.xlabel("Hours Studied")
plt.ylabel("Marks Received")
plt.title("Hours Studied vs Marks Received")
plt.show()

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df[['Hours_Studied']], df['Marks_received'])
# Out:
# LinearRegression()

# %%
#after fitting the model learnt this 
reg.coef_      # slope (m)
reg.intercept_ # intercept (b)
# Out:
# np.float64(31.645588235294134)

# %%
reg.predict([[3.12]])
# Out:
# C:\Users\Priti\my_stock_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([55.29335294])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(df.Hours_Studied, df.Marks_received,color='purple',marker='+')
plt.xlabel("Hours Studied")
plt.ylabel("Marks Received")
plt.title("Hours Studied vs Marks Received")
plt.plot(df.Hours_Studied, reg.predict(df[['Hours_Studied']]),color='blue')
