# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv("data.csv")
df
# Out:
#     Hours_Studied  Marks received
# 0             1.5              38
# 1             2.0              45
# 2             2.5              50
# 3             3.0              55
# 4             3.5              60
# 5             4.0              64
# 6             4.5              68
# 7             5.0              72
# 8             5.5              75
# 9             6.0              78
# 10            6.5              82
# 11            7.0              85
# 12            7.5              88
# 13            8.0              92
# 14            8.5              95
# 15            9.0              96

# %%
# %matplotlib inline
plt.scatter(df.rea,d)
